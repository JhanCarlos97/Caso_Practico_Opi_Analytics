# %% [markdown]
# <a href="https://www.opianalytics.com/"><img src = "https://pythondaymx.github.io/images/opi-analytics.png" width = 300></a>
#
# <h1 align=center><font size = 5>Resolución de caso práctico - Data Scientist</font></h1>

# %% [markdown]
# #### Instrucciones:
#
# ● Resuelve sólo una pregunta de la sección A, resuelve la pregunta de la sección B y
# resuelve el caso de la sección C.
#
# ● No se darán puntos adicionales si resuelves más de una pregunta por sección.
#
# ● Envía tus respuestas a más tardar 48 horas después de recibir el correo.
#
# ● Las respuestas podrán ser enviadas en un PDF, un notebook, o con un link a tu
# repositorio de GitHub.
#
# ● Debes especificar claramente las respuestas de cada inciso, e indicar el código usado.

# %% [markdown]
# <h2 align="center"><b>Sección B<b></h2>

# %% [markdown]
# Descarga la Base de datos histórica de <a href="https://datos.gob.mx/busca/dataset/quien-es-quien-en-los-precios/resource/d89a59ae-a42a-4d71-8c38-dd21d02027ab">Quién es Quién en los Precios</a> de Profeco y resuelve los siguientes incisos. Para el procesamiento de los datos y el análisis exploratorio debes debes usar Spark SQL en el lenguaje de programación de tu elección.
#
# 1. Procesamiento de los datos
#
#     a. ¿Cuántos registros hay?
#
#     b. ¿Cuántas categorías?
#
#     c. ¿Cuántas cadenas comerciales están siendo monitoreadas?
#
#     d. ¿Cómo podrías determinar la calidad de los datos? ¿Detectaste algún tipo de inconsistencia o error en la fuente?
#
#     e. ¿Cuáles son los productos más monitoreados en cada entidad?
#
#     f. ¿Cuál es la cadena comercial con mayor variedad de productos monitoreados?
#
#
# 2. Análisis exploratorio
#
#     a. Genera una canasta de productos básicos que te permita comparar los precios geográfica y temporalmente. Justifica tu elección y procedimiento
#
#     b. ¿Cuál es la ciudad más cara del país? ¿Cuál es la más barata?
#
#     c. ¿Hay algún patrón estacional entre años?
#
#     d. ¿Cuál es el estado más caro y en qué mes?
#
#     e. ¿Cuáles son los principales riesgos de hacer análisis de series de tiempo con estos datos?
#
#
# 3. Visualización
#
#     a. Genera un mapa que nos permita identificar la oferta de categorías en la zona metropolitana de León Guanajuato y el nivel de precios en cada una de ellas. Se darán puntos extra si el mapa es interactivo

# %% [markdown]
# ## Procesamiento de los datos:
#
# Para responder a lo anterior, haremos uso de PySpark y todas las funciones que ésta nos ofrece para el cálculo en grandes volúmenes:

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *

# %%
spark = SparkSession \
    .builder \
    .appName("Parte B para resolución caso práctico") \
    .config("spark.some.config.option", "some-value") \
    .getOrCreate()

# %%
data = spark.read.csv(
    "all_data.csv", 
    header=True)

# %%
data.show(3)
# Out:
# +--------------------+--------------------+--------+----------------+----------------+------+--------------------+------------------+----------+--------------------+--------------------+----------------+--------------------+--------+----------+
# |            producto|        presentacion|   marca|       categoria|        catalogo|precio|       fechaRegistro|   cadenaComercial|      giro|     nombreComercial|           direccion|          estado|           municipio| latitud|  longitud|
# +--------------------+--------------------+--------+----------------+----------------+------+--------------------+------------------+----------+--------------------+--------------------+----------------+--------------------+--------+----------+
# |CUADERNO FORMA IT...|96 HOJAS PASTA DU...|ESTRELLA|MATERIAL ESCOLAR|UTILES ESCOLARES|  25.9|2011-05-18 00:00:...|ABASTECEDORA LUMEN|PAPELERIAS|ABASTECEDORA LUME...|CANNES No. 6 ESQ....|DISTRITO FEDERAL|TLALPAN          ...|19.29699|-99.125417|
# |            CRAYONES|CAJA 12 CERAS. JU...| CRAYOLA|MATERIAL ESCOLAR|UTILES ESCOLARES|  27.5|2011-05-18 00:00:...|ABASTECEDORA LUMEN|PAPELERIAS|ABASTECEDORA LUME...|CANNES No. 6 ESQ....|DISTRITO FEDERAL|TLALPAN          ...|19.29699|-99.125417|
# |            CRAYONES|CAJA 12 CERAS. TA...| CRAYOLA|MATERIAL ESCOLAR|UTILES ESCOLARES|  13.9|2011-05-18 00:00:...|ABASTECEDORA LUMEN|PAPELERIAS|ABASTECEDORA LUME...|CANNES No. 6 ESQ....|DISTRITO FEDERAL|TLALPAN          ...|19.29699|-99.125417|
# +--------------------+--------------------+--------+----------------+----------------+------+--------------------+------------------+----------+--------------------+--------------------+----------------+--------------------+--------+----------+
# only showing top 3 rows

# %% [markdown]
# a) Para determinar la cantidad de datos en la tabla, haremos uso de .count(), así:

# %%
data.count()
# Out:
# 62530715

# %% [markdown]
# Lo que nos indique en la tabla, se tienen **62,530,715** registros.

# %%
data.createOrReplaceTempView("Tabla_temporal")

# %% [markdown]
# b) Para determinar la cantidad de categorías diferentes en nuestra tabla, hacemos uso de .sql(), ésta nos permite trabajar con la tabla a través de un query; aquí omitiremos las categorías nulas:

# %%
spark.sql("SELECT DISTINCT categoria FROM Tabla_temporal where categoria is not null").count()
# Out:
# 41

# %% [markdown]
# Así, nos dice, que existen **41** categorías diferentes clasificadas de manera oficial; las que figuran como nulas, no entran en ninguna de las **41** categorías.

# %% [markdown]
# c) Para éste interrogante, aplicamos la misma lógica, pero en éste caso, para la columna de cadenaComercial:

# %%
spark.sql("SELECT DISTINCT cadenaComercial FROM Tabla_temporal where cadenaComercial is not null").count()
# Out:
# 705

# %% [markdown]
# Así, tenemos que se están monitoreando **705** cadenas comerciales, aquí, los que no registran como cadena comercial, se les asigna el valor nulo.

# %% [markdown]
# d) Para determinar la calidad de los datos, podemos hacer un barrido sencillo para los casos donde se registren valores nulos en alguna de las filas en la tabla:

# %%
columnas = data.columns

# %%
for columna in columnas:
    print(columna)
    print(data.filter(data[columna].isNotNull()).count())
    print("")
# Out:
# producto
# 62530715
#
# presentacion
# 62530715
#
# marca
# 62530715
#
# categoria
# 61643377
#
# catalogo
# 62530487
#
# precio
# 62530715
#
# fechaRegistro
# 62530715
#
# cadenaComercial
# 62529531
#
# giro
# 62530428
#
# nombreComercial
# 62530715
#
# direccion
# 62530715
#
# estado
# 62515661
#
# municipio
# 62515661
#
# latitud
# 62493901
#
# longitud
# 62493901

# %% [markdown]
# Analicemos qué sucede en cada columna con respecto a los valores y en el caso de los valores nulos:

# %%
for columna in columnas:
    query_datos =  "SELECT DISTINCT "+columna+" FROM Tabla_temporal order by "+columna+" asc"
    query_vista_5_nulos = "SELECT * FROM Tabla_temporal where "+columna+" is null"
    datos = spark.sql(query_datos)
    datos.show()
    vista_5_nulos = spark.sql(query_vista_5_nulos)
    if vista_5_nulos.count() > 0:
        vista_5_nulos.show(5)
# Out:
# +--------------------+
# |            producto|
# +--------------------+
# |"PREMARIN. CREMA ...|
# |             A.S.COR|
# |             ABILIFY|
# |            ACARBOSA|
# |              ACEITE|
# |     ACEITE DE OLIVA|
# |            ACEITUNA|
# |    ACEITUNA. GORDAL|
# |ACEITUNA. MANZANILLA|
# |ACEITUNA. RELLENA...|
# |              ACELGA|
# |           ACICLOVIR|
# |   ACIDO ALENDRONICO|
# |        ACIDO FOLICO|
# |ACIDO NALIDIXICO ...|
# |           ACLIMAFEL|
# |             ACLORAL|
# |ACONDICIONADOR / ...|
# |ACONDICIONADOR DE...|
# |ACONDICIONADOR Y ...|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+
# |        presentacion|
# +--------------------+
# |# 6017872 O C.B. ...|
# |# 6019459  O  C.B...|
# |# 6019464 O C.B. ...|
# |# 6019660  O C.B....|
# |# 6020580 O C.B. ...|
# |#703377 O 75484 O...|
# |#703378 O 75491 O...|
# |#703470  O  66079...|
# |#706856 Ó MOD. 75...|
# |''F''  CAJA CON 1...|
# |     00009. MONOPOLY|
# |00322. CUBO DE FO...|
# |0140808. PATIN BA...|
# |0140819. PATIN/SC...|
# |0160133. TRICICLO...|
# |0160808. PATIN. L...|
# |01611 C.B.33903. ...|
# |01746. ACTION MAN...|
# |01901. ACTION MAN...|
# |01902. ACTION MAN...|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+
# |               marca|
# +--------------------+
# |'PAPER MATE. ERAS...|
# |               1 2 3|
# |            1 MINUTO|
# |               1-2-3|
# |      120 SANTA RITA|
# |     120. SANTA RITA|
# |                1880|
# |           3 MINUTOS|
# |                7 UP|
# |ABBOTT LABORATORI...|
# |ABBOTT LABORATORI...|
# |            ABUELITA|
# |ACADEMIA 3O. Y 4O...|
# |ACADEMIA 5O. Y 6O...|
# |ACADEMIA BASICO E...|
# |ACADEMIA. ESCOLAR...|
# |  ACADEMIA. ESCOLAR.|
# |ACADEMIA. SECUNDA...|
# |ACADEMIA. SECUNDA...|
# |ACCION Y REACCION...|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+
# |           categoria|
# +--------------------+
# |                null|
# |ACCESORIOS DOMEST...|
# |ACEITES Y GRASAS ...|
# | APARATOS ELECTRICOS|
# |APARATOS ELECTRON...|
# |ARROZ Y CEREALES ...|
# |ARTS. DE ESPARCIM...|
# |ARTS. DE PAPEL P/...|
# |ARTS. PARA EL CUI...|
# |              AZUCAR|
# |                CAFE|
# |        CARNE DE AVE|
# |CARNE Y VISCERAS ...|
# |CARNE Y VISCERAS ...|
# |CARNES FRIAS SECA...|
# |             CERVEZA|
# |CHOCOLATES Y GOLO...|
# |         CIGARRILLOS|
# |         CONDIMENTOS|
# |  DERIVADOS DE LECHE|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------------------+--------------------+---------+--------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------+---------+---------+----------+
# |            producto|        presentacion|               marca|categoria|catalogo|precio|       fechaRegistro|     cadenaComercial|                giro|     nombreComercial|           direccion|estado|municipio|  latitud|  longitud|
# +--------------------+--------------------+--------------------+---------+--------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------+---------+---------+----------+
# |              ACEITE|BOTELLA 946 ML. M...|           SABROSANO|     null| BASICOS|  19.5|2016-04-01 12:04:...|BODEGA COMERCIAL ...|TIENDA DE AUTOSER...|BODEGA COMERCIAL ...|CENTRAL 50, ENTRE...|MÉXICO| ECATEPEC|19.516095|-99.035105|
# |CONCENTRADO DE POLLO|CAJA 110 GR. 10 C...|          RIKO POLLO|     null| BASICOS|  15.9|2016-04-01 12:05:...|BODEGA COMERCIAL ...|TIENDA DE AUTOSER...|BODEGA COMERCIAL ...|CENTRAL 50, ENTRE...|MÉXICO| ECATEPEC|19.516095|-99.035105|
# |POLVO P/BEBIDAS S...|       BOLSA 375 GR.|        GOLDEN HILLS|     null| BASICOS| 15.95|2016-04-01 12:00:...|BODEGA COMERCIAL ...|TIENDA DE AUTOSER...|BODEGA COMERCIAL ...|CENTRAL 50, ENTRE...|MÉXICO| ECATEPEC|19.516095|-99.035105|
# |     LECHE EVAPORADA|DESCREMADA. LATA ...|CARNATION. CLAVEL...|     null| BASICOS| 12.35|2016-04-01 12:02:...|BODEGA COMERCIAL ...|TIENDA DE AUTOSER...|BODEGA COMERCIAL ...|CENTRAL 50, ENTRE...|MÉXICO| ECATEPEC|19.516095|-99.035105|
# |            CEREALES|CAJA 620 GR. FLAK...|  ALL-BRAN KELLOGG'S|     null| BASICOS|    53|2016-04-01 12:03:...|BODEGA COMERCIAL ...|TIENDA DE AUTOSER...|BODEGA COMERCIAL ...|CENTRAL 50, ENTRE...|MÉXICO| ECATEPEC|19.516095|-99.035105|
# +--------------------+--------------------+--------------------+---------+--------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------+---------+---------+----------+
# only showing top 5 rows
#
# +--------------------+
# |            catalogo|
# +--------------------+
# |                null|
# |             BASICOS|
# |   ELECTRODOMESTICOS|
# |  FRUTAS Y LEGUMBRES|
# |            JUGUETES|
# |        MEDICAMENTOS|
# |            MERCADOS|
# |           NAVIDEÑOS|
# | PESCADOS Y MARISCOS|
# |REGIONALES MONTERREY|
# |               TENIS|
# |    UTILES ESCOLARES|
# |            catalogo|
# +--------------------+
#
# +--------------------+------------+----------+--------------------+--------+------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+---------+----------+
# |            producto|presentacion|     marca|           categoria|catalogo|precio|       fechaRegistro|     cadenaComercial|                giro|     nombreComercial|           direccion|          estado|           municipio|  latitud|  longitud|
# +--------------------+------------+----------+--------------------+--------+------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+---------+----------+
# |CHILES LARGOS EN ...|LATA 400 GR.|SAN MARCOS|PRODUCTOS DE TEMP...|    null|  15.4|2011-11-10 00:00:...|MEGA COMERCIAL ME...|TIENDA DE AUTOSER...|MEGA COMERCIAL ME...|BOULEVARD JOSE TO...|      GUANAJUATO|LEON             ...|21.095156|-101.62957|
# |CHILES LARGOS EN ...|LATA 400 GR.|SAN MARCOS|PRODUCTOS DE TEMP...|    null|  15.4|2011-11-10 00:00:...|MEGA COMERCIAL ME...|TIENDA DE AUTOSER...|MEGA COMERCIAL ME...|AV. GUSTAVO BAZ N...|          MÉXICO|TLALNEPANTLA     ...|19.547688| -99.20706|
# |CHILES LARGOS EN ...|LATA 400 GR.|SAN MARCOS|PRODUCTOS DE TEMP...|    null|  14.9|2011-11-10 00:00:...|            WAL-MART|TIENDA DE AUTOSER...|WAL MART SUCURSAL...|AUTOPISTA MEXICO ...|          MÉXICO|TLALNEPANTLA     ...|19.547246|-99.209564|
# |CHILES LARGOS EN ...|LATA 400 GR.|SAN MARCOS|PRODUCTOS DE TEMP...|    null|  14.5|2011-11-10 00:00:...|            SUPERAMA|TIENDA DE AUTOSER...|SUPERAMA SUCURSAL...|AV. DIVISION DEL ...|DISTRITO FEDERAL|COYOACAN         ...|19.320886|-99.139021|
# |CHILES LARGOS EN ...|LATA 400 GR.|SAN MARCOS|PRODUCTOS DE TEMP...|    null|  14.9|2011-11-10 00:00:...|            WAL-MART|TIENDA DE AUTOSER...|WAL MART SUCURSAL...|AV. CUITLAHUAC NO...|DISTRITO FEDERAL|AZCAPOTZALCO     ...|19.471594| -99.16484|
# +--------------------+------------+----------+--------------------+--------+------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------+--------------------+---------+----------+
# only showing top 5 rows
#
# +------+
# |precio|
# +------+
# |   .57|
# |   .60|
# |   .70|
# |   .80|
# |   .83|
# |   .90|
# |   0.1|
# |  0.25|
# |  0.45|
# |   0.5|
# |  0.55|
# |   0.6|
# |  0.64|
# |  0.65|
# |  0.68|
# |   0.7|
# |  0.75|
# |   0.8|
# |  0.81|
# |  0.82|
# +------+
# only showing top 20 rows
#
# +--------------------+
# |       fechaRegistro|
# +--------------------+
# |2011-01-03 00:00:...|
# |2011-01-04 00:00:...|
# |2011-01-05 00:00:...|
# |2011-01-06 00:00:...|
# |2011-01-07 00:00:...|
# |2011-01-08 00:00:...|
# |2011-01-10 00:00:...|
# |2011-01-11 00:00:...|
# |2011-01-12 00:00:...|
# |2011-01-13 00:00:...|
# |2011-01-14 00:00:...|
# |2011-01-15 00:00:...|
# |2011-01-17 00:00:...|
# |2011-01-18 00:00:...|
# |2011-01-19 00:00:...|
# |2011-01-20 00:00:...|
# |2011-01-21 00:00:...|
# |2011-01-22 00:00:...|
# |2011-01-24 00:00:...|
# |2011-01-25 00:00:...|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+
# |     cadenaComercial|
# +--------------------+
# |                null|
# |            7 ELEVEN|
# |ABARROTERA DE BAJ...|
# |ABARROTERA DE TLA...|
# |ABARROTERA GUADAL...|
# |ABARROTERA MONTERREY|
# |  ABARROTERA SANCHEZ|
# |   ABARROTES APIZACO|
# |     ABARROTES ARTES|
# |ABARROTES LA VIOLETA|
# |    ABARROTES MEXICO|
# |ABARROTES SUPER C...|
# |ABARROTES SUPER R...|
# |      ABARROTES VERO|
# |     ABARROTES VIRGO|
# |ABARROTES Y VINOS...|
# |  ABASTECEDORA LUMEN|
# |               ADOSA|
# | ALMACENES EL AGUILA|
# |    ALMACENES GARCIA|
# +--------------------+
# only showing top 20 rows
# +--------------+--------------------+---------+------------+------------+------+--------------------+---------------+--------------------+--------------------+--------------------+------+--------------------+-------+--------+
# |      producto|        presentacion|    marca|   categoria|    catalogo|precio|       fechaRegistro|cadenaComercial|                giro|     nombreComercial|           direccion|estado|           municipio|latitud|longitud|
# +--------------+--------------------+---------+------------+------------+------+--------------------+---------------+--------------------+--------------------+--------------------+------+--------------------+-------+--------+
# |  DOLOCARTIGEN|CAJA CON 20 CAPSU...|      S/M|MEDICAMENTOS|MEDICAMENTOS| 586.4|2013-05-10 00:00:...|           null|FARMACIA BOTICA Y...|FARMACIA NUEVA IM...|AV. SAN FERNANDO ...|COLIMA|COLIMA           ...|     NA|      NA|
# |CELESTAMINE-NS|CAJA CON FRASCO 6...|      S/M|MEDICAMENTOS|MEDICAMENTOS|279.28|2013-05-10 00:00:...|           null|FARMACIA BOTICA Y...|FARMACIA NUEVA IM...|AV. SAN FERNANDO ...|COLIMA|COLIMA           ...|     NA|      NA|
# |DOLO-NEUROBION|CAJA CON FRASCO C...|      S/M|MEDICAMENTOS|MEDICAMENTOS|231.71|2013-05-10 00:00:...|           null|FARMACIA BOTICA Y...|FARMACIA NUEVA IM...|AV. SAN FERNANDO ...|COLIMA|COLIMA           ...|     NA|      NA|
# |        AMARYL|CAJA CON 15 TABLE...|SIN MARCA|MEDICAMENTOS|MEDICAMENTOS|437.13|2013-05-10 00:00:...|           null|FARMACIA BOTICA Y...|FARMACIA NUEVA IM...|AV. SAN FERNANDO ...|COLIMA|COLIMA           ...|     NA|      NA|
# |      CYMBALTA|CAJA CON 7 CAPSUL...|      S/M|MEDICAMENTOS|MEDICAMENTOS|333.63|2013-05-10 00:00:...|           null|FARMACIA BOTICA Y...|FARMACIA NUEVA IM...|AV. SAN FERNANDO ...|COLIMA|COLIMA           ...|     NA|      NA|
# +--------------+--------------------+---------+------------+------------+------+--------------------+---------------+--------------------+--------------------+--------------------+------+--------------------+-------+--------+
# only showing top 5 rows
#
# +--------------------+
# |                giro|
# +--------------------+
# |                null|
# |ARTICULOS DEPORTIVOS|
# |   CENTRAL DE ABASTO|
# |FARMACIA BOTICA Y...|
# |         JUGUETERIAS|
# |           LIBRERIAS|
# |   MERCADO AMBULANTE|
# |     MERCADO PUBLICO|
# |           MUEBLERIA|
# |PANADERIA Y PASTE...|
# |          PAPELERIAS|
# | PESCADOS Y MARISCOS|
# |SALCHICHONERIA TO...|
# | TIENDA DE ABARROTES|
# |TIENDA DE AUTOSER...|
# |TIENDA DE CONVENI...|
# |TIENDA DE ELECTRO...|
# |TIENDA DEPARTAMENTAL|
# |         TORTILLERIA|
# | UNIFORMES ESCOLARES|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------------------+---------+--------------------+--------+------+--------------------+---------------+----+-------------------+--------------------+-------+--------------------+--------+-----------+
# |            producto|        presentacion|    marca|           categoria|catalogo|precio|       fechaRegistro|cadenaComercial|giro|    nombreComercial|           direccion| estado|           municipio| latitud|   longitud|
# +--------------------+--------------------+---------+--------------------+--------+------+--------------------+---------------+----+-------------------+--------------------+-------+--------------------+--------+-----------+
# |         VIDEOJUEGOS|X BOX 360. PES 20...|MICROSOFT|ARTS. DE ESPARCIM...|JUGUETES|   899|2013-12-12 00:00:...|         GAMERS|null|GAMERS SUCURSAL 098|AV. ALVARO OBREGÓ...|SINALOA|CULIACAN         ...|24.80579|-107.394626|
# |         VIDEOJUEGOS|X BOX 360 KINECT....|MICROSOFT|ARTS. DE ESPARCIM...|JUGUETES|   499|2013-12-12 00:00:...|         GAMERS|null|GAMERS SUCURSAL 098|AV. ALVARO OBREGÓ...|SINALOA|CULIACAN         ...|24.80579|-107.394626|
# |ELECTRONICOS DE V...|VIDEOCONSOLA. PS3...|     SONY|ARTS. DE ESPARCIM...|JUGUETES|  4499|2013-12-12 00:00:...|         GAMERS|null|GAMERS SUCURSAL 098|AV. ALVARO OBREGÓ...|SINALOA|CULIACAN         ...|24.80579|-107.394626|
# |ELECTRONICOS DE V...|VIDEOCONSOLA. X B...|MICROSOFT|ARTS. DE ESPARCIM...|JUGUETES|  3999|2013-12-12 00:00:...|         GAMERS|null|GAMERS SUCURSAL 098|AV. ALVARO OBREGÓ...|SINALOA|CULIACAN         ...|24.80579|-107.394626|
# |ELECTRONICOS DE V...|VIDEOCONSOLA. PS3...|     SONY|ARTS. DE ESPARCIM...|JUGUETES|  5499|2013-12-12 00:00:...|         GAMERS|null|GAMERS SUCURSAL 098|AV. ALVARO OBREGÓ...|SINALOA|CULIACAN         ...|24.80579|-107.394626|
# +--------------------+--------------------+---------+--------------------+--------+------+--------------------+---------------+----+-------------------+--------------------+-------+--------------------+--------+-----------+
# only showing top 5 rows
#
# +--------------------+
# |     nombreComercial|
# +--------------------+
# |            7 ELEVEN|
# |7 ELEVEN  SUCURSA...|
# |7 ELEVEN SUCUESAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |7 ELEVEN SUCURSAL...|
# |ABAROTES LA CONTI...|
# |   ABARROTERA AZTECA|
# |ABARROTERA DE TLA...|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+
# |           direccion|
# +--------------------+
# |"CALZ. LAZARO CAR...|
# |"ORIENTE 100 """"...|
# |"ORIENTE 100-A # ...|
# |05 DE MAYO 202, P...|
# |1 DE MAYO 103, EN...|
# |1 DE MAYO 103, EN...|
# |1 DE MAYO 42, COL...|
# |    1 DE MAYO NO. 42|
# |10 DE JULIO S/N L...|
# |10 DE JULIO S/N L...|
# |10 ORIENTE 4, ENT...|
# |10 ORIENTE NO. 4,...|
# |11 AV. S/N, ENTRE...|
# |11 SUR 3104, ENTR...|
# |11 SUR 9503, MERC...|
# |11 SUR 9503, MERC...|
# |12 DE OCT. NO. 21...|
# |12 DE OCTUBRE 210...|
# |12 DE OCTUBRE 303...|
# |12 DE OCTUBRE 303...|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+
# |              estado|
# +--------------------+
# |                null|
# | COL. EDUARDO GUERRA|
# |       ESQ. SUR 125"|
# |      AGUASCALIENTES|
# |     BAJA CALIFORNIA|
# | BAJA CALIFORNIA SUR|
# |            CAMPECHE|
# |             CHIAPAS|
# |           CHIHUAHUA|
# |COAHUILA DE ZARAGOZA|
# |              COLIMA|
# |    DISTRITO FEDERAL|
# |             DURANGO|
# |          GUANAJUATO|
# |            GUERRERO|
# |             HIDALGO|
# |             JALISCO|
# | MICHOACÁN DE OCAMPO|
# |             MORELOS|
# |              MÉXICO|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------------------+-------------------+---------------+--------+------+--------------------+------------------+--------------------+------------------+--------------------+------+---------+-------+--------+
# |            producto|        presentacion|              marca|      categoria|catalogo|precio|       fechaRegistro|   cadenaComercial|                giro|   nombreComercial|           direccion|estado|municipio|latitud|longitud|
# +--------------------+--------------------+-------------------+---------------+--------+------+--------------------+------------------+--------------------+------------------+--------------------+------+---------+-------+--------+
# |  LECHE PASTEURIZADA|  ENTERA. CAJA 1 LT.|    ALPURA. CLASICA|LECHE PROCESADA| BASICOS|  11.7|2011-06-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |LECHE ULTRAPASTEU...|PARCIALMENTE DESC...|ALPURA 2000 CLASICA|LECHE PROCESADA| BASICOS|  12.5|2011-06-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |LECHE ULTRAPASTEU...|PARCIALMENTE DESC...|ALPURA 2000 CLASICA|LECHE PROCESADA| BASICOS|  13.5|2011-10-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |  LECHE PASTEURIZADA|  ENTERA. CAJA 1 LT.|    ALPURA. CLASICA|LECHE PROCESADA| BASICOS|  12.5|2011-10-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |  LECHE PASTEURIZADA|  ENTERA. CAJA 1 LT.|    ALPURA. CLASICA|LECHE PROCESADA| BASICOS|  11.7|2011-06-01 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# +--------------------+--------------------+-------------------+---------------+--------+------+--------------------+------------------+--------------------+------------------+--------------------+------+---------+-------+--------+
# only showing top 5 rows
# +--------------------+
# |           municipio|
# +--------------------+
# |                null|
# |          CP. 27280"|
# |ACAPULCO DE JUARE...|
# |  ACAPULCO DE JUÁREZ|
# |         AGUA PRIETA|
# |AGUA PRIETA      ...|
# |      AGUASCALIENTES|
# |AGUASCALIENTES   ...|
# |ALVARO OBREGON   ...|
# |             APIZACO|
# |APIZACO          ...|
# |             APODACA|
# |APODACA          ...|
# |ATIZAPAN         ...|
# |ATIZAPAN DE ZARAG...|
# |            ATIZAPÁN|
# |ATIZAPÁN DE ZARAGOZA|
# |        AZCAPOTZALCO|
# |AZCAPOTZALCO     ...|
# |BENITO JUAREZ    ...|
# +--------------------+
# only showing top 20 rows
#
# +--------------------+--------------------+-------------------+---------------+--------+------+--------------------+------------------+--------------------+------------------+--------------------+------+---------+-------+--------+
# |            producto|        presentacion|              marca|      categoria|catalogo|precio|       fechaRegistro|   cadenaComercial|                giro|   nombreComercial|           direccion|estado|municipio|latitud|longitud|
# +--------------------+--------------------+-------------------+---------------+--------+------+--------------------+------------------+--------------------+------------------+--------------------+------+---------+-------+--------+
# |  LECHE PASTEURIZADA|  ENTERA. CAJA 1 LT.|    ALPURA. CLASICA|LECHE PROCESADA| BASICOS|  11.7|2011-06-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |LECHE ULTRAPASTEU...|PARCIALMENTE DESC...|ALPURA 2000 CLASICA|LECHE PROCESADA| BASICOS|  12.5|2011-06-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |LECHE ULTRAPASTEU...|PARCIALMENTE DESC...|ALPURA 2000 CLASICA|LECHE PROCESADA| BASICOS|  13.5|2011-10-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |  LECHE PASTEURIZADA|  ENTERA. CAJA 1 LT.|    ALPURA. CLASICA|LECHE PROCESADA| BASICOS|  12.5|2011-10-10 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# |  LECHE PASTEURIZADA|  ENTERA. CAJA 1 LT.|    ALPURA. CLASICA|LECHE PROCESADA| BASICOS|  11.7|2011-06-01 00:00:...|COMERCIAL MEXICANA|TIENDA DE AUTOSER...|COMERCIAL MEXICANA|AV. TOLTECAS No. 318|  null|     null|     NA|      NA|
# +--------------------+--------------------+-------------------+---------------+--------+------+--------------------+------------------+--------------------+------------------+--------------------+------+---------+-------+--------+
# only showing top 5 rows
#
# +---------+
# |  latitud|
# +---------+
# |     null|
# |        0|
# |14.874144|
# |14.876276|
# |14.893368|
# |14.893675|
# |14.896359|
# | 14.89882|
# |14.899328|
# |14.901735|
# |14.901826|
# |14.902499|
# | 14.90327|
# |14.903815|
# |14.904001|
# |14.905669|
# |14.905819|
# |14.907869|
# |14.908914|
# |14.909399|
# +---------+
# only showing top 20 rows
#
# +--------------------+--------------------+----------+--------------------+--------+------+--------------------+---------------+--------------------+--------------------+--------------------+------------+-------------+-------+--------+
# |            producto|        presentacion|     marca|           categoria|catalogo|precio|       fechaRegistro|cadenaComercial|                giro|     nombreComercial|           direccion|      estado|    municipio|latitud|longitud|
# +--------------------+--------------------+----------+--------------------+--------+------+--------------------+---------------+--------------------+--------------------+--------------------+------------+-------------+-------+--------+
# |    TORTILLA DE MAIZ|        1 KG. GRANEL|       S/M|TORTILLAS Y DERIV...| BASICOS|  9.50|2016-01-11 08:10:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# |ALIMENTO PREPARAD...|FRASCO 170 GR. A ...|    GERBER|FRUTAS Y LEGUMBRE...| BASICOS| 12.90|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# |ALIMENTO PREPARAD...|FRASCO 113 GR. A ...|    GERBER|FRUTAS Y LEGUMBRE...| BASICOS| 10.50|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# | PAÑALES DESECHABLES|PAQUETE 38 PIEZAS...|KLEEN BEBE|ARTS. DE PAPEL P/...| BASICOS| 79.00|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# | PAÑALES DESECHABLES|PAQUETE 38 PIEZAS...|KLEEN BEBE|ARTS. DE PAPEL P/...| BASICOS|135.00|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# +--------------------+--------------------+----------+--------------------+--------+------+--------------------+---------------+--------------------+--------------------+--------------------+------------+-------------+-------+--------+
# only showing top 5 rows
#
# +-----------+
# |   longitud|
# +-----------+
# |       null|
# |-100.220247|
# |-100.224383|
# | -100.22893|
# |-100.232137|
# |-100.237902|
# |-100.240632|
# |-100.243159|
# |-100.244832|
# |-100.255254|
# |-100.258833|
# |-100.261696|
# |-100.265544|
# |-100.271316|
# |-100.277233|
# |-100.280567|
# |-100.283056|
# |-100.285218|
# |-100.286977|
# |-100.287447|
# +-----------+
# only showing top 20 rows
#
# +--------------------+--------------------+----------+--------------------+--------+------+--------------------+---------------+--------------------+--------------------+--------------------+------------+-------------+-------+--------+
# |            producto|        presentacion|     marca|           categoria|catalogo|precio|       fechaRegistro|cadenaComercial|                giro|     nombreComercial|           direccion|      estado|    municipio|latitud|longitud|
# +--------------------+--------------------+----------+--------------------+--------+------+--------------------+---------------+--------------------+--------------------+--------------------+------------+-------------+-------+--------+
# |    TORTILLA DE MAIZ|        1 KG. GRANEL|       S/M|TORTILLAS Y DERIV...| BASICOS|  9.50|2016-01-11 08:10:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# |ALIMENTO PREPARAD...|FRASCO 170 GR. A ...|    GERBER|FRUTAS Y LEGUMBRE...| BASICOS| 12.90|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# |ALIMENTO PREPARAD...|FRASCO 113 GR. A ...|    GERBER|FRUTAS Y LEGUMBRE...| BASICOS| 10.50|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# | PAÑALES DESECHABLES|PAQUETE 38 PIEZAS...|KLEEN BEBE|ARTS. DE PAPEL P/...| BASICOS| 79.00|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# | PAÑALES DESECHABLES|PAQUETE 38 PIEZAS...|KLEEN BEBE|ARTS. DE PAPEL P/...| BASICOS|135.00|2016-01-11 08:12:...|       CHEDRAUI|TIENDA DE AUTOSER...|CHEDRAUI SUCURSAL...|TULUM 57 Y 59, EN...|QUINTANA ROO|BENITO JUÁREZ|   null|    null|
# +--------------------+--------------------+----------+--------------------+--------+------+--------------------+---------------+--------------------+--------------------+--------------------+------------+-------------+-------+--------+
# only showing top 5 rows

# %% [markdown]
# Con éste loop pudimos identificar que en los datos, existían numerosos valores nulos en varias columnas, como por ejemplo, la columna de **categoria**, seguida de las columnas de **latitud** y **longitud**.
#
# Además, pudimos observar que en cada columna, existian valores, que aunque no son nulos, son inconsistentes, ejemplo; para la columna *producto* existe un producto que en esa columna solo es nombrado **producto**, al igual que en la columna de *catalogo*; otro detalle por ejemplo, es que en la columna *estado* existen registros de una entidad federativa llamada **ESQ. SUR 125"**, que no registra como ninguna de las entidades federativas del gobierno mexicano.

# %% [markdown]
# Además, en caso de hacerse la respectiva eliminación de todos esos registros nulos (por columna), nos quedará en total:

# %%
for columna in columnas:
    data = data.filter(data[columna].isNotNull())
data.count()
# Out:
# 61593576

# %% [markdown]
# Con esto, nos quedamos con cerca del **98,5%** de los datos originales,de los cuales, fueron suprimidos por arrojar valores nulos en alguna de sus columnas.

# %% [markdown]
#    e) Para observar cuales son los productos más monitoreados basta con hacer una consulta con .sql :

# %%
entidades = spark.sql("SELECT distinct(estado) as entidad from Tabla_temporal").select('entidad').rdd.flatMap(lambda x: x).collect()

# %%
entidades = list(filter(None, entidades))

# %% [markdown]
# Aquí podemos ver los 3 productos más monitoreados por cada entidad federativa:

# %%
for entidad in entidades:
    query_por_entidad = "SELECT producto, count(producto) as cantidad FROM Tabla_temporal where producto is not null and estado = '"+entidad+"' and estado is not null GROUP BY producto ORDER BY cantidad desc"
    data_entidad = spark.sql(query_por_entidad)
    print (entidad)
    data_entidad.show(3)
# Out:
# QUINTANA ROO
# +---------+--------+
# | producto|cantidad|
# +---------+--------+
# |      FUD|   34846|
# | REFRESCO|   34367|
# |LAVADORAS|   32347|
# +---------+--------+
# only showing top 3 rows
#
# NUEVO LEÓN
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |   DETERGENTE P/ROPA|   50307|
# |            REFRESCO|   49592|
# |LECHE ULTRAPASTEU...|   43803|
# +--------------------+--------+
# only showing top 3 rows
#
# SINALOA
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   33115|
# |DETERGENTE P/ROPA|   27177|
# |          SHAMPOO|   22435|
# +-----------------+--------+
# only showing top 3 rows
#
# TABASCO
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   28754|
# |DETERGENTE P/ROPA|   26431|
# |        LAVADORAS|   26361|
# +-----------------+--------+
# only showing top 3 rows
#
# BAJA CALIFORNIA
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   37243|
# |DETERGENTE P/ROPA|   23395|
# |              FUD|   19967|
# +-----------------+--------+
# only showing top 3 rows
#
# TLAXCALA
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |            REFRESCO|   43904|
# |   DETERGENTE P/ROPA|   41398|
# |LECHE ULTRAPASTEU...|   32169|
# +--------------------+--------+
# only showing top 3 rows
#
# COAHUILA DE ZARAGOZA
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |              FUD|   28613|
# |         REFRESCO|   26889|
# |DETERGENTE P/ROPA|   26595|
# +-----------------+--------+
# only showing top 3 rows
#
#  ESQ. SUR 125"
# +------------------+--------+
# |          producto|cantidad|
# +------------------+--------+
# |PAN BLANCO BOLILLO|     130|
# |  TORTILLA DE MAIZ|       2|
# +------------------+--------+
#
# CHIAPAS
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   14452|
# |              FUD|   10417|
# |DETERGENTE P/ROPA|    8831|
# +-----------------+--------+
# only showing top 3 rows
#
#  COL. EDUARDO GUERRA
# +----------------+--------+
# |        producto|cantidad|
# +----------------+--------+
# |        REFRESCO|     275|
# |JABON DE TOCADOR|     270|
# |             FUD|     263|
# +----------------+--------+
# only showing top 3 rows
#
# VERACRUZ DE IGNACIO DE LA LLAVE
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |            REFRESCO|   14576|
# |LECHE ULTRAPASTEU...|   12051|
# |   DETERGENTE P/ROPA|   10345|
# +--------------------+--------+
# only showing top 3 rows
#
# SONORA
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   34731|
# |DETERGENTE P/ROPA|   31997|
# |          SHAMPOO|   24758|
# +-----------------+--------+
# only showing top 3 rows
#
# YUCATÁN
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |LECHE ULTRAPASTEU...|   35991|
# |   DETERGENTE P/ROPA|   33390|
# |            REFRESCO|   33235|
# +--------------------+--------+
# only showing top 3 rows
#
# MICHOACÁN DE OCAMPO
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |   DETERGENTE P/ROPA|   40144|
# |            REFRESCO|   38016|
# |LECHE ULTRAPASTEU...|   31175|
# +--------------------+--------+
# only showing top 3 rows
#
# DURANGO
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |DETERGENTE P/ROPA|    9696|
# |        LAVADORAS|    9644|
# |              FUD|    8866|
# +-----------------+--------+
# only showing top 3 rows
#
# GUERRERO
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|    8932|
# |              FUD|    8846|
# |DETERGENTE P/ROPA|    6455|
# +-----------------+--------+
# only showing top 3 rows
#
# NAYARIT
# +---------+--------+
# | producto|cantidad|
# +---------+--------+
# | REFRESCO|    8003|
# |PANTALLAS|    7083|
# |      FUD|    6644|
# +---------+--------+
# only showing top 3 rows
#
# CHIHUAHUA
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |DETERGENTE P/ROPA|   15982|
# |              FUD|   14348|
# |   CHILES EN LATA|   14189|
# +-----------------+--------+
# only showing top 3 rows
#
# DISTRITO FEDERAL
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |            REFRESCO|  287463|
# |                 FUD|  207569|
# |LECHE ULTRAPASTEU...|  175640|
# +--------------------+--------+
# only showing top 3 rows
#
# estado
# +--------+--------+
# |producto|cantidad|
# +--------+--------+
# |producto|      20|
# +--------+--------+
#
# HIDALGO
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   18137|
# |        LAVADORAS|   16519|
# |DETERGENTE P/ROPA|   15946|
# +-----------------+--------+
# only showing top 3 rows
#
# ZACATECAS
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |   DETERGENTE P/ROPA|   20884|
# |LECHE ULTRAPASTEU...|   17309|
# |           LAVADORAS|   16072|
# +--------------------+--------+
# only showing top 3 rows
#
# GUANAJUATO
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   49441|
# |DETERGENTE P/ROPA|   36618|
# |           VARIOS|   35278|
# +-----------------+--------+
# only showing top 3 rows
#
# SAN LUIS POTOSÍ
# +---------+--------+
# | producto|cantidad|
# +---------+--------+
# |      FUD|   10164|
# |PANTALLAS|    8662|
# |LAVADORAS|    7934|
# +---------+--------+
# only showing top 3 rows
#
# TAMAULIPAS
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|   22457|
# |              FUD|   21113|
# |DETERGENTE P/ROPA|   20291|
# +-----------------+--------+
# only showing top 3 rows
#
# MORELOS
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|    9632|
# |              FUD|    6909|
# |DETERGENTE P/ROPA|    5829|
# +-----------------+--------+
# only showing top 3 rows
#
# AGUASCALIENTES
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |                 FUD|   12005|
# |   DETERGENTE P/ROPA|   10188|
# |LECHE ULTRAPASTEU...|    9824|
# +--------------------+--------+
# only showing top 3 rows
#
# OAXACA
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |LECHE ULTRAPASTEU...|   18078|
# |            REFRESCO|   14501|
# |   DETERGENTE P/ROPA|   14396|
# +--------------------+--------+
# only showing top 3 rows
#
# PUEBLA
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |            REFRESCO|   31597|
# |           LAVADORAS|   27076|
# |LECHE ULTRAPASTEU...|   24864|
# +--------------------+--------+
# only showing top 3 rows
#
# BAJA CALIFORNIA SUR
# +---------+--------+
# | producto|cantidad|
# +---------+--------+
# | REFRESCO|   27770|
# |      FUD|   17776|
# |PANTALLAS|   17383|
# +---------+--------+
# only showing top 3 rows
#
# JALISCO
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |            REFRESCO|   81718|
# |LECHE ULTRAPASTEU...|   81149|
# |   DETERGENTE P/ROPA|   73854|
# +--------------------+--------+
# only showing top 3 rows
#
# CAMPECHE
# +---------+--------+
# | producto|cantidad|
# +---------+--------+
# |      FUD|   12960|
# | REFRESCO|   11333|
# |PANTALLAS|   10449|
# +---------+--------+
# only showing top 3 rows
#
# QUERÉTARO
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |LECHE ULTRAPASTEU...|   27868|
# |   DETERGENTE P/ROPA|   26700|
# |            REFRESCO|   25494|
# +--------------------+--------+
# only showing top 3 rows
#
# COLIMA
# +--------------------+--------+
# |            producto|cantidad|
# +--------------------+--------+
# |   DETERGENTE P/ROPA|   17193|
# |LECHE ULTRAPASTEU...|   14425|
# |            REFRESCO|   14383|
# +--------------------+--------+
# only showing top 3 rows
#
# MÉXICO
# +-----------------+--------+
# |         producto|cantidad|
# +-----------------+--------+
# |         REFRESCO|  194939|
# |              FUD|  149141|
# |DETERGENTE P/ROPA|  132862|
# +-----------------+--------+
# only showing top 3 rows

# %% [markdown]
# f) Para ésta pregunta, veremos:

# %%
query_cadena_mayor_variedad = "SELECT cadenaComercial,count(DISTINCT(producto)) AS productos_distintos from Tabla_temporal GROUP BY cadenaComercial ORDER BY productos_distintos desc"
spark.sql(query_cadena_mayor_variedad).show(10)
# Out:
# +--------------------+-------------------+
# |     cadenaComercial|productos_distintos|
# +--------------------+-------------------+
# |             SORIANA|               1059|
# |            WAL-MART|               1051|
# |MEGA COMERCIAL ME...|               1049|
# |  COMERCIAL MEXICANA|               1036|
# |            CHEDRAUI|               1026|
# |     MERCADO SORIANA|               1024|
# |      BODEGA AURRERA|               1012|
# |HIPERMERCADO SORIANA|               1006|
# |              H.E.B.|               1001|
# |        SORIANA PLUS|                999|
# +--------------------+-------------------+
# only showing top 10 rows

# %% [markdown]
# Con esto vemos que la cadena comercial con mayor variedad de productos monitoreados es **Soriana** con **1059** artículos distintos registrados.

# %% [markdown]
# ## Análisis Exploratorio

# %% [markdown]
# a) Para poder determinar una canasta de productos básicos, debemos sustraer los productos que estén en ese catálogo, y que además, existan registro de ellos en cada una de las entidades federativas.

# %%
data_tiempo_geo = spark.sql("SELECT producto,presentacion, avg(precio), fechaRegistro, estado, municipio from Tabla_temporal where catalogo='BASICOS' AND precio is not null GROUP BY producto, fechaRegistro, estado, municipio, presentacion")
data_tiempo_geo.show(10)
# Out:
# +--------------------+--------------------+---------------------------+--------------------+----------------+--------------------+
# |            producto|        presentacion|avg(CAST(precio AS DOUBLE))|       fechaRegistro|          estado|           municipio|
# +--------------------+--------------------+---------------------------+--------------------+----------------+--------------------+
# |   GELATINA EN POLVO|CAJA 84 GR. AGUA....|                        6.7|2011-01-10 00:00:...|          MÉXICO|ATIZAPAN         ...|
# |       SALSA PICANTE|BOTELLA 370 ML. E...|                        5.0|2011-01-10 00:00:...|          MÉXICO|ATIZAPAN         ...|
# |      CHILES EN LATA|LATA 215 GR. JALA...|          6.066666666666666|2011-01-10 00:00:...|DISTRITO FEDERAL|BENITO JUAREZ    ...|
# |    JABON DE TOCADOR|CAJA CON BARRA 10...|                       12.1|2011-01-10 00:00:...|DISTRITO FEDERAL|BENITO JUAREZ    ...|
# |      CHILES EN LATA|LATA 220 GR. JALA...|          6.013333333333333|2011-01-10 00:00:...|DISTRITO FEDERAL|BENITO JUAREZ    ...|
# |         DESODORANTE|  BARRA 60 GR. FRESH|         31.096666666666668|2011-01-10 00:00:...|DISTRITO FEDERAL|IZTACALCO        ...|
# |     GALLETAS DULCES|CAJA 752 GR. SAND...|                      36.24|2011-01-10 00:00:...|DISTRITO FEDERAL|IZTACALCO        ...|
# |SHAMPOO PARA BEBE...|BOTELLA 265 ML. 2...|                      37.95|2011-01-10 00:00:...|          MÉXICO|NAUCALPAN        ...|
# |ACEITUNA. MANZANILLA|1 KG. GRANEL. ACE...|                       66.5|2011-01-10 00:00:...|DISTRITO FEDERAL|BENITO JUAREZ    ...|
# |   DETERGENTE P/ROPA|BOLSA 1 KG. POLVO...|                       16.9|2011-01-10 00:00:...|DISTRITO FEDERAL|BENITO JUAREZ    ...|
# +--------------------+--------------------+---------------------------+--------------------+----------------+--------------------+
# only showing top 10 rows

# %% [markdown]
# Con esto, tenemos los productos que se registran en todas las ciudades y sus precios promedio por fecha, para proceder, debemos determinar cuales son esos productos que están en todas las ciudades y luego, de los que satisfacen esa condición, serán los productos de la canasta básica mexicana.
#
# Posteriormente
# Procedemos de esa forma para poder deshacernos de aquellos productos que no se tienen registro, salvo en ciertas zonas específicas. Para hablar de una canasta familiar mexicana, se debe realizar como lo anterior, algo que se consuma en todos lados y que se venden en todos los lugares de las entidades federativas.
#
# Además, como queremos analizar producto, lugar y tiempo específicos, debemos extraer la ubicación al menos por estado y municipio, esto para establecer un precio promedio en una misma ciudad.

# %% [markdown]
# b) Para esto, tomamos los precios promedios registrados a la fecha más reciente (lo ideal seria considerar todo un mes completo, no una fecha específica) en los registros de cada ciudad, sumamos estos por municipio y éste será el que nos determinará el costo de una canasta de productos básicos; así, se toma el municipio con el indicidor más alto y con el indicador más bajo.

# %% [markdown]
# c) Agrupamos por meses para cada año el costo total promedio de la canasta de productos básico, desarrollamos una gráfica y observamos por algún patrón entre las series de tiempo.

# %% [markdown]
# d) Para esto, consideremos el comportamiento del indicador para el último mes; entonces tomamos el último mes registrado, agrupamos por estado y tomamos los precios promedios agrupados por estado, sumamos los valores de cada elemento en la canasta de productos básicos; así, se toma el estado con el indicador más alto.

# %% [markdown]
# e) La ausencia de datos en periodos de tiempo, ya que pueden existir registros donde la frecuencia de muestreo es menor que en otras; así, si se deseara comparar precios a día, surgirán errores.

# %% [markdown]
# ## Visualización
#
# Ésta parte se puede desarrollar filtrando la información para el municipio de León, Guanajuato; agrupamos por categoría, determinamos el precio promedio por categoría en cada comercio, y señalamos ésta información en el comercio(nombreComercial) y su ubicación en un mapa.
#
# Lo ideal, sería implementar una dropdown para la lista de categorías y sean éstas las que se muestren en el popup que hace referencia al comercio.
